# %%
#!/usr/bin/env python
# coding: utf-8

# %pip install seaborn
import DataPreprocessing as dp


# In[2]:


dp.preprocess()


# In[ ]:


import seaborn as sns
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3 -> 22.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# processing file:  data/WESAD/S2/S2.pkl
# wrist_bvp shape:  (389056, 1)
# wrist_eda shape:  (24316, 1)
# wrist_temp shape:  (24316, 1)
# wrist_acc shape:  (194528, 3)
# lbl_acc.shape : (194528, 1)
# lbl_bvp.shape : (389056, 1)
# lbl_eda_temp.shape : (24316, 1)
# md1.shape:  (194528, 5)
# md2.shape:  (389056, 3)
# md3.shape:  (24316, 4)
#
# processing file:  data/WESAD/S3/S3.pkl
# wrist_bvp shape:  (415552, 1)
# wrist_eda shape:  (25972, 1)
# wrist_temp shape:  (25972, 1)
# wrist_acc shape:  (207776, 3)
# lbl_acc.shape : (207776, 1)
# lbl_bvp.shape : (415552, 1)
# lbl_eda_temp.shape : (25972, 1)
# last_subj1.shape:  (207776, 5)
# last_subj2.shape:  (415552, 3)
# last_subj3.shape:  (25972, 4)
# md1.shape:  (402304, 5)
# md2.shape:  (804608, 3)
# md3.shape:  (50288, 4)
#
# ...

# %%
from ae_feature_extractor import autoencoder


ae = autoencoder ()
ae.train_model_c ()
ae.extract_features()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3504/849391809.py in <module>
# ----> 1 from ae_feature_extractor import autoencoder
#       2
#       3
#       4 ae = autoencoder ()
#       5 ae.train_model_c ()
#
# ~\Documents\Jupyter\WESAD\ae_feature_extractor.py in <module>
#       7 from scipy import stats
#       8 from sklearn.preprocessing import StandardScaler
# ----> 9 from keras.layers import Input, Dense, Flatten, Reshape, BatchNormalization
#      10 from keras.layers import Conv1D, UpSampling1D, MaxPooling1D, AveragePooling1D
#      11 from keras.models import Model, Sequential
#
# ModuleNotFoundError: No module named 'keras'
